# %% [markdown]
# ### Basic model, all auto

# %%
from autogluon import TabularPrediction as task
import pandas as pd

train_data = pd.read_csv("../data/train.csv")
test_data = pd.read_csv("../data/test.csv")

# %%
predictor = task.fit(train_data=task.Dataset(df=train_data), label='Survived')
predictions = predictor.predict(task.Dataset(df=test_data))
# Out:
# No output_directory specified. Models will be saved in: AutogluonModels/ag-20201009_041322/
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20201009_041322/
# AutoGluon Version:  0.0.14
# Train Data Rows:    891
# Train Data Columns: 11
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6761.64 MB
# 	Train Data (Original)  Memory Usage: 0.31 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['Name']
# 			CountVectorizer fit with vocabulary size = 8
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])        : 2 | ['Age', 'Fare']
# 		('int', [])          : 4 | ['PassengerId', 'Pclass', 'SibSp', 'Parch']
# 		('object', [])       : 4 | ['Sex', 'Ticket', 'Cabin', 'Embarked']
# 		('object', ['text']) : 1 | ['Name']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :  4 | ['Sex', 'Ticket', 'Cabin', 'Embarked']
# 		('float', [])                       :  2 | ['Age', 'Fare']
# 		('int', [])                         :  4 | ['PassengerId', 'Pclass', 'SibSp', 'Parch']
# 		('int', ['binned', 'text_special']) : 12 | ['Name.char_count', 'Name.word_count', 'Name.capital_ratio', 'Name.lower_ratio', 'Name.special_ratio', ...]
# 		('int', ['text_ngram'])             :  9 | ['__nlp__.henry', '__nlp__.john', '__nlp__.master', '__nlp__.miss', '__nlp__.mr', ...]
# 	0.7s = Fit runtime
# 	11 features in original data used to generate 31 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.73s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: 'accuracy'
# Fitting model: RandomForestClassifierGini ...
# 	0.8268	 = Validation accuracy score
# 	0.4s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestClassifierEntr ...
# 	0.8268	 = Validation accuracy score
# 	0.4s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesClassifierGini ...
# 	0.8156	 = Validation accuracy score
# 	0.31s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesClassifierEntr ...
# 	0.8101	 = Validation accuracy score
# 	0.32s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: KNeighborsClassifierUnif ...
# 	0.648	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsClassifierDist ...
# 	0.648	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMClassifier ...
# 	0.8212	 = Validation accuracy score
# 	0.24s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMClassifierXT ...
# 	0.8101	 = Validation accuracy score
# 	0.21s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatboostClassifier ...
# 	0.838	 = Validation accuracy score
# 	0.54s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetClassifier ...
# 	0.8212	 = Validation accuracy score
# 	4.64s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMClassifierCustom ...
# 	0.8212	 = Validation accuracy score
# 	0.43s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# 	0.8492	 = Validation accuracy score
# 	0.25s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 9.2s ...

# %%
# Prediction to series
predictions_ser = pd.Series(predictions)

# Load passenger IDs, combine with predictions
test_ids = pd.read_csv("../data/test.csv")
test_ids = test_ids['PassengerId']

submission = pd.DataFrame({'PassengerId': test_ids, 'Survived': predictions_ser})

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
# submission.to_csv("../submissions/kaggle_titanic_autogluon.csv", index=False)

# %% [markdown]
# ##### Under the Hood

# %%
results = predictor.fit_summary()
results.values()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                          model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      weighted_ensemble_k0_l1   0.860335       0.175934  8.537685                0.000494           0.249768            1       True         12
# 1           CatboostClassifier   0.837989       0.007581  0.653054                0.007581           0.653054            0       True          9
# 2          NeuralNetClassifier   0.837989       0.029880  5.449867                0.029880           5.449867            0       True         10
# 3   RandomForestClassifierGini   0.826816       0.034246  0.419742                0.034246           0.419742            0       True          1
# 4   RandomForestClassifierEntr   0.826816       0.035457  0.402485                0.035457           0.402485            0       True          2
# 5     LightGBMClassifierCustom   0.821229       0.008506  0.465446                0.008506           0.465446            0       True         11
# 6           LightGBMClassifier   0.821229       0.008976  0.302886                0.008976           0.302886            0       True          7
# 7     ExtraTreesClassifierGini   0.815642       0.036567  0.319553                0.036567           0.319553            0       True          3
# 8         LightGBMClassifierXT   0.810056       0.008536  0.273390                0.008536           0.273390            0       True          8
# 9     ExtraTreesClassifierEntr   0.810056       0.035205  0.317480                0.035205           0.317480            0       True          4
# 10    KNeighborsClassifierDist   0.648045       0.007053  0.003567                0.007053           0.003567            0       True          6
# 11    KNeighborsClassifierUnif   0.648045       0.007650  0.003046                0.007650           0.003046            0       True          5
# Number of models trained: 12
# Types of models trained:
# {'XTModel', 'CatboostModel', 'TabularNeuralNetModel', 'LGBModel', 'RFModel', 'KNNModel', 'WeightedEnsembleModel'}
# Bagging used: False
# Stack-ensembling used: False
# Hyperparameter-tuning used: False
# User-specified hyperparameters:
# {'default': {'NN': [{}], 'GBM': [{}, {'extra_trees': True, 'AG_args': {'name_suffix': 'XT'}}], 'CAT': [{}], 'RF': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'XT': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'KNN': [{'weights': 'uniform', 'AG_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'AG_args': {'name_suffix': 'Dist'}}], 'custom': [{'num_boost_round': 10000, 'num_threads': -1, 'objective': 'binary', 'verbose': -1, 'boosting_type': 'gbdt', 'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5, 'two_round': True, 'seed_value': 0, 'AG_args': {'model_type': 'GBM', 'name_suffix': 'Custom', 'disable_in_hpo': True}}]}}
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])                    :  4 | ['Sex', 'Ticket', 'Cabin', 'Embarked']
# ('float', [])                       :  2 | ['Age', 'Fare']
# ('int', [])                         :  4 | ['PassengerId', 'Pclass', 'SibSp', 'Parch']
# ('int', ['binned', 'text_special']) : 12 | ['Name.char_count', 'Name.word_count', 'Name.capital_ratio', 'Name.lower_ratio', 'Name.special_ratio', ...]
# ('int', ['text_ngram'])             :  9 | ['__nlp__.henry', '__nlp__.john', '__nlp__.master', '__nlp__.miss', '__nlp__.mr', ...]
# Plot summary of models saved to file: AutogluonModels/ag-20201009_000033/SummaryOfModels.html
# *** End of fit() summary ***
# dict_values([{'RandomForestClassifierGini': 'RFModel', 'RandomForestClassifierEntr': 'RFModel', 'ExtraTreesClassifierGini': 'XTModel', 'ExtraTreesClassifierEntr': 'XTModel', 'KNeighborsClassifierUnif': 'KNNModel', 'KNeighborsClassifierDist': 'KNNModel', 'LightGBMClassifier': 'LGBModel', 'LightGBMClassifierXT': 'LGBModel', 'CatboostClassifier': 'CatboostModel', 'NeuralNetClassifier': 'TabularNeuralNetModel', 'LightGBMClassifierCustom': 'LGBModel', 'weighted_ensemble_k0_l1': 'WeightedEnsembleModel'}, {'RandomForestClassifierGini': 0.8268156424581006, 'RandomForestClassifierEntr': 0.8268156424581006, 'ExtraTreesClassifierGini': 0.8156424581005587, 'ExtraTreesClassifierEntr': 0.8100558659217877, 'KNeighborsClassifierUnif': 0.6480446927374302, 'KNeighborsClassifierDist': 0.6480446927374302, 'LightGBMClassifier': 0.8212290502793296, 'LightGBMClassifierXT': 0.8100558659217877, 'CatboostClassifier': 0.8379888268156425, 'NeuralNetClassifier': 0.8379888268156425, 'LightGBMClassifierCustom': 0.8212290502793296, 'weighted_ensemble_k0_l1': 0.8603351955307262}, 'weighted_ensemble_k0_l1', {'RandomForestClassifierGini': 'AutogluonModels/ag-20201009_000033/models/RandomForestClassifierGini/', 'RandomForestClassifierEntr': 'AutogluonModels/ag-20201009_000033/models/RandomForestClassifierEntr/', 'ExtraTreesClassifierGini': 'AutogluonModels/ag-20201009_000033/models/ExtraTreesClassifierGini/', 'ExtraTreesClassifierEntr': 'AutogluonModels/ag-20201009_000033/models/ExtraTreesClassifierEntr/', 'KNeighborsClassifierUnif': 'AutogluonModels/ag-20201009_000033/models/KNeighborsClassifierUnif/', 'KNeighborsClassifierDist': 'AutogluonModels/ag-20201009_000033/models/KNeighborsClassifierDist/', 'LightGBMClassifier': 'AutogluonModels/ag-20201009_000033/models/LightGBMClassifier/', 'LightGBMClassifierXT': 'AutogluonModels/ag-20201009_000033/models/LightGBMClassifierXT/', 'CatboostClassifier': 'AutogluonModels/ag-20201009_000033/models/CatboostClassifier/', 'NeuralNetClassifier': 'AutogluonModels/ag-20201009_000033/models/NeuralNetClassifier/', 'LightGBMClassifierCustom': 'AutogluonModels/ag-20201009_000033/models/LightGBMClassifierCustom/', 'weighted_ensemble_k0_l1': 'AutogluonModels/ag-20201009_000033/models/weighted_ensemble_k0_l1/'}, {'RandomForestClassifierGini': 0.4197421073913574, 'RandomForestClassifierEntr': 0.4024848937988281, 'ExtraTreesClassifierGini': 0.3195528984069824, 'ExtraTreesClassifierEntr': 0.31748008728027344, 'KNeighborsClassifierUnif': 0.003045797348022461, 'KNeighborsClassifierDist': 0.0035669803619384766, 'LightGBMClassifier': 0.3028860092163086, 'LightGBMClassifierXT': 0.2733900547027588, 'CatboostClassifier': 0.6530539989471436, 'NeuralNetClassifier': 5.449867010116577, 'LightGBMClassifierCustom': 0.46544575691223145, 'weighted_ensemble_k0_l1': 0.24976778030395508}, {'RandomForestClassifierGini': 0.034245967864990234, 'RandomForestClassifierEntr': 0.03545713424682617, 'ExtraTreesClassifierGini': 0.03656721115112305, 'ExtraTreesClassifierEntr': 0.03520464897155762, 'KNeighborsClassifierUnif': 0.007650136947631836, 'KNeighborsClassifierDist': 0.0070531368255615234, 'LightGBMClassifier': 0.008975982666015625, 'LightGBMClassifierXT': 0.008536100387573242, 'CatboostClassifier': 0.007580757141113281, 'NeuralNetClassifier': 0.029880046844482422, 'LightGBMClassifierCustom': 0.008506059646606445, 'weighted_ensemble_k0_l1': 0.0004940032958984375}, 0, 0, False, False, {'default': {'NN': [{}], 'GBM': [{}, {'extra_trees': True, 'AG_args': {'name_suffix': 'XT'}}], 'CAT': [{}], 'RF': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'XT': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'KNN': [{'weights': 'uniform', 'AG_args': {'nam ...
# 0      weighted_ensemble_k0_l1   0.860335       0.175934  8.537685
# 1           CatboostClassifier   0.837989       0.007581  0.653054
# 2          NeuralNetClassifier   0.837989       0.029880  5.449867
# 3   RandomForestClassifierGini   0.826816       0.034246  0.419742
# 4   RandomForestClassifierEntr   0.826816       0.035457  0.402485
# 5     LightGBMClassifierCustom   0.821229       0.008506  0.465446
# 6           LightGBMClassifier   0.821229       0.008976  0.302886
# 7     ExtraTreesClassifierGini   0.815642       0.036567  0.319553
# 8         LightGBMClassifierXT   0.810056       0.008536  0.273390
# 9     ExtraTreesClassifierEntr   0.810056       0.035205  0.317480
# 10    KNeighborsClassifierDist   0.648045       0.007053  0.003567
# 11    KNeighborsClassifierUnif   0.648045       0.007650  0.003046
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000494           0.249768            1       True
# 1                 0.007581           0.653054            0       True
# 2                 0.029880           5.449867            0       True
# 3                 0.034246           0.419742            0       True
# 4                 0.035457           0.402485            0       True
# 5                 0.008506           0.465446            0       True
# 6                 0.008976           0.302886            0       True
# 7                 0.036567           0.319553            0       True
# 8                 0.008536           0.273390            0       True
# 9                 0.035205           0.317480            0       True
# 10                0.007053           0.003567            0       True
# 11                0.007650           0.003046            0       True
#
#     fit_order
# 0          12
# 1           9
# 2          10
# 3           1
# 4           2
# 5          11
# 6           7
# 7           3
# 8           8
# 9           4
# 10          6
# 11          5  ])

# %%
predictor.feature_importance(dataset=train_data)
# Out:
# Computing raw permutation importance for 11 features on weighted_ensemble_k0_l1 ...
# 	3.23s	= Expected runtime
# 	3.14s	= Actual runtime
# Sex            0.111111
# Name           0.072952
# Pclass         0.044893
# Ticket         0.039282
# PassengerId    0.019080
# Cabin          0.015713
# Fare           0.014590
# Embarked       0.008979
# Age            0.008979
# Parch          0.003367
# SibSp          0.003367
# dtype: float64

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
